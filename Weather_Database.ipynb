# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

#Import library
import requests 

#Import API key 
from config import weather_api_key
from config import g_key 

#Import time 
from datetime import datetime 

#Import citipy 
from citipy import citipy

# %%
# Create a set of random latitudes and longitudes combinations
lats = np.random.uniform(low = -90.00, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list 
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 791

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e43cf2ff3dd723d916a3acbdadfe7598

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters 
record_count = 1
set_count = 1 

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ossora
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | mahebourg
# Processing Record 4 of Set 1 | codrington
# Processing Record 5 of Set 1 | tilichiki
# Processing Record 6 of Set 1 | tuatapere
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 1 | imuris
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | algeciras
# Processing Record 12 of Set 1 | melekhovskaya
# City not found. Skipping...
# Processing Record 13 of Set 1 | cairns
# Processing Record 14 of Set 1 | saint-joseph
# Processing Record 15 of Set 1 | tongliao
# Processing Record 16 of Set 1 | sept-iles
# Processing Record 17 of Set 1 | aviles
# Processing Record 18 of Set 1 | henties bay
# Processing Record 19 of Set 1 | sechura
# Processing Record 20 of Set 1 | brahmapuri
# City not found. Skipping...
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | vestmannaeyjar
# Processing Record 23 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | fortuna
# Processing Record 27 of Set 1 | torbay
# Processing Record 28 of Set 1 | zapolyarnyy
# Processing Record 29 of Set 1 | ayagoz
# Processing Record 30 of Set 1 | bathsheba
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | rolim de moura
# City not found. Skipping...
# Processing Record 33 of Set 1 | ribeira grande
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | vostok
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | souillac
# Processing Record 40 of Set 1 | lavrentiya
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | norman wells
# Processing Record 44 of Set 1 | georgetown
# Processing Record 45 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 1 | council bluffs
# Processing Record 48 of Set 1 | wasilla
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | todos santos
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | leh
# Processing Record 4 of Set 2 | parintins
# Processing Record 5 of Set 2 | clyde river
# Processing Record 6 of Set 2 | khatanga
# Processing Record 7 of Set 2 | manakara
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | norwich
# Processing Record 10 of Set 2 | tocoa
# Processing Record 11 of Set 2 | starobaltachevo
# Processing Record 12 of Set 2 | tiksi
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 2 | bambous virieux
# Processing Record 16 of Set 2 | oranjemund
# Processing Record 17 of Set 2 | vicksburg
# Processing Record 18 of Set 2 | flin flon
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | jaisalmer
# Processing Record 22 of Set 2 | navashino
# Processing Record 23 of Set 2 | flinders
# Processing Record 24 of Set 2 | chapais
# Processing Record 25 of Set 2 | isangel
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | bambanglipuro
# Processing Record 28 of Set 2 | gunjur
# Processing Record 29 of Set 2 | kodiak
# Processing Record 30 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 2 | huarmey
# Processing Record 32 of Set 2 | bethel
# Processing Record 33 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 2 | portland
# Processing Record 35 of Set 2 | yelizovo
# Processing Record 36 of Set 2 | khani
# Processing Record 37 of Set 2 | nikolskoye
# Processing Record 38 of Set 2 | cururupu
# Processing Record 39 of Set 2 | tasiilaq
# Processing Record 40 of Set 2 | sitka
# Processing Record 41 of Set 2 | nyuksenitsa
# Processing Record 42 of Set 2 | bonthe
# Processing Record 43 of Set 2 | chokwe
# Processing Record 44 of Set 2 | tatarsk
# Processing Record 45 of Set 2 | coquimbo
# Processing Record 46 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 47 of Set 2 | ghatampur
# Processing Record 48 of Set 2 | visakhapatnam
# Processing Record 49 of Set 2 | leningradskiy
# Processing Record 50 of Set 2 | hobart
# Processing Record 1 of Set 3 | anadyr
# Processing Record 2 of Set 3 | vanimo
# Processing Record 3 of Set 3 | bismarck
# Processing Record 4 of Set 3 | constitucion
# Processing Record 5 of Set 3 | castro
# Processing Record 6 of Set 3 | west wendover
# Processing Record 7 of Set 3 | fukue
# Processing Record 8 of Set 3 | batouri
# Processing Record 9 of Set 3 | port macquarie
# Processing Record 10 of Set 3 | najran
# Processing Record 11 of Set 3 | naze
# Processing Record 12 of Set 3 | ust-maya
# Processing Record 13 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 3 | severo-kurilsk
# Processing Record 15 of Set 3 | severobaykalsk
# Processing Record 16 of Set 3 | ilulissat
# Processing Record 17 of Set 3 | jamestown
# Processing Record 18 of Set 3 | port elizabeth
# Processing Record 19 of Set 3 | longyearbyen
# Processing Record 20 of Set 3 | bengkulu
# Processing Record 21 of Set 3 | gordeyevka
# Processing Record 22 of Set 3 | sheridan
# Processing Record 23 of Set 3 | sharlyk
# Processing Record 24 of Set 3 | vao
# Processing Record 25 of Set 3 | yining
# Processing Record 26 of Set 3 | russell
# Processing Record 27 of Set 3 | amuntai
# Processing Record 28 of Set 3 | butaritari
# Processing Record 29 of Set 3 | carutapera
# Processing Record 30 of Set 3 | durant
# Processing Record 31 of Set 3 | honiara
# Processing Record 32 of Set 3 | kavaratti
# Processing Record 33 of Set 3 | sahrak
# City not found. Skipping...
# Processing Record 34 of Set 3 | port-cartier
# Processing Record 35 of Set 3 | dzilam gonzalez
# Processing Record 36 of Set 3 | ikom
# Processing Record 37 of Set 3 | manaus
# Processing Record 38 of Set 3 | lambari
# Processing Record 39 of Set 3 | labuhan
# Processing Record 40 of Set 3 | omsukchan
# Processing Record 41 of Set 3 | malindi
# Processing Record 42 of Set 3 | arman
# Processing Record 43 of Set 3 | formosa do rio preto
# Processing Record 44 of Set 3 | saint-francois
# Processing Record 45 of Set 3 | lompoc
# Processing Record 46 of Set 3 | alindao
# Processing Record 47 of Set 3 | ewa beach
# Processing Record 48 of Set 3 | tsumeb
# Processing Record 49 of Set 3 | vanavara
# Processing Record 50 of Set 3 | atar
# Processing Record 1 of Set 4 | tomatlan
# Processing Record 2 of Set 4 | narsaq
# Processing Record 3 of Set 4 | akcakoca
# Processing Record 4 of Set 4 | upernavik
# Processing Record 5 of Set 4 | zabaykalsk
# Processing Record 6 of Set 4 | grafton
# Processing Record 7 of Set 4 | beloha
# Processing Record 8 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 4 | porto novo
# Processing Record 10 of Set 4 | iqaluit
# Processing Record 11 of Set 4 | neryungri
# Processing Record 12 of Set 4 | khorixas
# Processing Record 13 of Set 4 | eyl
# Processing Record 14 of Set 4 | ust-kuyga
# Processing Record 15 of Set 4 | lingyuan
# Processing Record 16 of Set 4 | zeya
# Processing Record 17 of Set 4 | banda aceh
# Processing Record 18 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 4 | bairiki
# Processing Record 20 of Set 4 | sampit
# Processing Record 21 of Set 4 | haines junction
# Processing Record 22 of Set 4 | arraial do cabo
# Processing Record 23 of Set 4 | shimminato
# Processing Record 24 of Set 4 | hami
# Processing Record 25 of Set 4 | aykhal
# Processing Record 26 of Set 4 | katsuura
# Processing Record 27 of Set 4 | mendi
# Processing Record 28 of Set 4 | cape town
# Processing Record 29 of Set 4 | north platte
# Processing Record 30 of Set 4 | mattawa
# Processing Record 31 of Set 4 | mehamn
# Processing Record 32 of Set 4 | touros
# Processing Record 33 of Set 4 | chuy
# Processing Record 34 of Set 4 | tuensang
# Processing Record 35 of Set 4 | morada nova
# Processing Record 36 of Set 4 | ondangwa
# Processing Record 37 of Set 4 | matay
# Processing Record 38 of Set 4 | chokurdakh
# Processing Record 39 of Set 4 | mokhsogollokh
# Processing Record 40 of Set 4 | northam
# Processing Record 41 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 4 | salalah
# Processing Record 43 of Set 4 | road town
# Processing Record 44 of Set 4 | deputatskiy
# Processing Record 45 of Set 4 | nagarote
# Processing Record 46 of Set 4 | wilhelmshaven
# Processing Record 47 of Set 4 | balkhash
# Processing Record 48 of Set 4 | marawi
# Processing Record 49 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 50 of Set 4 | methoni
# Processing Record 1 of Set 5 | san carlos de bariloche
# Processing Record 2 of Set 5 | dunedin
# Processing Record 3 of Set 5 | novorzhev
# Processing Record 4 of Set 5 | sur
# Processing Record 5 of Set 5 | esperance
# Processing Record 6 of Set 5 | stabat
# Processing Record 7 of Set 5 | husavik
# Processing Record 8 of Set 5 | pevek
# Processing Record 9 of Set 5 | barrow
# Processing Record 10 of Set 5 | trairi
# Processing Record 11 of Set 5 | sulangan
# Processing Record 12 of Set 5 | chattanooga
# Processing Record 13 of Set 5 | mar del plata
# Processing Record 14 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 5 | gat
# Processing Record 16 of Set 5 | thompson
# Processing Record 17 of Set 5 | cuencame
# Processing Record 18 of Set 5 | pemangkat
# Processing Record 19 of Set 5 | taoudenni
# Processing Record 20 of Set 5 | dingle
# Processing Record 21 of Set 5 | rodrigues alves
# Processing Record 22 of Set 5 | saldanha
# Processing Record 23 of Set 5 | celestun
# Processing Record 24 of Set 5 | geraldton
# Processing Record 25 of Set 5 | tessalit
# Processing Record 26 of Set 5 | port hedland
# Processing Record 27 of Set 5 | huari
# Processing Record 28 of Set 5 | sapao
# City not found. Skipping...
# Processing Record 29 of Set 5 | faya
# Processing Record 30 of Set 5 | sabancuy
# Processing Record 31 of Set 5 | puerto leguizamo
# Processing Record 32 of Set 5 | grand gaube
# Processing Record 33 of Set 5 | ukiah
# Processing Record 34 of Set 5 | saint george
# Processing Record 35 of Set 5 | coihaique
# Processing Record 36 of Set 5 | saint-philippe
# Processing Record 37 of Set 5 | broome
# Processing Record 38 of Set 5 | mandan
# Processing Record 39 of Set 5 | sinnamary
# Processing Record 40 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 5 | meulaboh
# Processing Record 42 of Set 5 | umm lajj
# Processing Record 43 of Set 5 | hambantota
# Processing Record 44 of Set 5 | buala
# Processing Record 45 of Set 5 | palmerston
# Processing Record 46 of Set 5 | altamira
# Processing Record 47 of Set 5 | provideniya
# Processing Record 48 of Set 5 | promysla
# City not found. Skipping...
# Processing Record 49 of Set 5 | tena
# Processing Record 50 of Set 5 | port hawkesbury
# Processing Record 1 of Set 6 | yenagoa
# Processing Record 2 of Set 6 | gemena
# Processing Record 3 of Set 6 | dikson
# Processing Record 4 of Set 6 | puerto baquerizo moreno
# Processing Record 5 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 6 | shache
# Processing Record 7 of Set 6 | maldonado
# Processing Record 8 of Set 6 | tlahualilo
# City not found. Skipping...
# Processing Record 9 of Set 6 | talnakh
# Processing Record 10 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 11 of Set 6 | tuktoyaktuk
# Processing Record 12 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 6 | kozhevnikovo
# Processing Record 14 of Set 6 | ponta do sol
# Processing Record 15 of Set 6 | homer
# Processing Record 16 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 6 | comodoro rivadavia
# Processing Record 18 of Set 6 | pitimbu
# Processing Record 19 of Set 6 | wloszczowa
# Processing Record 20 of Set 6 | bluff
# Processing Record 21 of Set 6 | falam
# Processing Record 22 of Set 6 | emporia
# Processing Record 23 of Set 6 | zemio
# Processing Record 24 of Set 6 | lebu
# Processing Record 25 of Set 6 | burkhala
# City not found. Skipping...
# Processing Record 26 of Set 6 | raudeberg
# Processing Record 27 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 6 | yerofey pavlovich
# Processing Record 29 of Set 6 | issoire
# Processing Record 30 of Set 6 | caucaia
# Processing Record 31 of Set 6 | luyang
# Processing Record 32 of Set 6 | lilongwe
# Processing Record 33 of Set 6 | cayenne
# Processing Record 34 of Set 6 | ivanteyevka
# Processing Record 35 of Set 6 | christchurch
# Processing Record 36 of Set 6 | tianpeng
# Processing Record 37 of Set 6 | pudozh
# Processing Record 38 of Set 6 | caraquet
# Processing Record 39 of Set 6 | faanui
# Processing Record 40 of Set 6 | enkoping
# Processing Record 41 of Set 6 | margate
# Processing Record 42 of Set 6 | x-can
# City not found. Skipping...
# Processing Record 43 of Set 6 | pattukkottai
# Processing Record 44 of Set 6 | marystown
# Processing Record 45 of Set 6 | rumford
# Processing Record 46 of Set 6 | pedernales
# Processing Record 47 of Set 6 | fenoarivo
# Processing Record 48 of Set 6 | denpasar
# Processing Record 49 of Set 6 | batticaloa
# Processing Record 50 of Set 6 | komsomolskiy
# Processing Record 1 of Set 7 | omboue
# Processing Record 2 of Set 7 | ust-ilimsk
# Processing Record 3 of Set 7 | xuzhou
# Processing Record 4 of Set 7 | la romana
# Processing Record 5 of Set 7 | teknaf
# Processing Record 6 of Set 7 | bonavista
# Processing Record 7 of Set 7 | lagoa
# Processing Record 8 of Set 7 | selty
# Processing Record 9 of Set 7 | coalcoman
# City not found. Skipping...
# Processing Record 10 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 7 | mogoytuy
# Processing Record 12 of Set 7 | timizart
# Processing Record 13 of Set 7 | libreville
# Processing Record 14 of Set 7 | hofn
# Processing Record 15 of Set 7 | bahia de caraquez
# Processing Record 16 of Set 7 | horsham
# Processing Record 17 of Set 7 | mancio lima
# Processing Record 18 of Set 7 | micheweni
# Processing Record 19 of Set 7 | noumea
# Processing Record 20 of Set 7 | manono
# Processing Record 21 of Set 7 | winslow
# Processing Record 22 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 7 | victoria
# Processing Record 24 of Set 7 | kavieng
# Processing Record 25 of Set 7 | hay river
# Processing Record 26 of Set 7 | half moon bay
# Processing Record 27 of Set 7 | inta
# Processing Record 28 of Set 7 | benicarlo
# Processing Record 29 of Set 7 | airai
# Processing Record 30 of Set 7 | ati
# Processing Record 31 of Set 7 | la rochelle
# Processing Record 32 of Set 7 | marihatag
# Processing Record 33 of Set 7 | tabas
# Processing Record 34 of Set 7 | saint-augustin
# Processing Record 35 of Set 7 | salinas
# Processing Record 36 of Set 7 | east london
# Processing Record 37 of Set 7 | cidreira
# Processing Record 38 of Set 7 | aksu
# Processing Record 39 of Set 7 | zaokskiy
# Processing Record 40 of Set 7 | ushibuka
# Processing Record 41 of Set 7 | lima
# Processing Record 42 of Set 7 | klaksvik
# Processing Record 43 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 44 of Set 7 | hasaki
# Processing Record 45 of Set 7 | iringa
# Processing Record 46 of Set 7 | pisco
# Processing Record 47 of Set 7 | akle
# Processing Record 48 of Set 7 | pinotepa nacional
# Processing Record 49 of Set 7 | amahai
# Processing Record 50 of Set 7 | abu samrah
# Processing Record 1 of Set 8 | cowra
# Processing Record 2 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 8 | panzos
# Processing Record 4 of Set 8 | tautira
# Processing Record 5 of Set 8 | tura
# Processing Record 6 of Set 8 | balad
# Processing Record 7 of Set 8 | leshukonskoye
# Processing Record 8 of Set 8 | kahului
# Processing Record 9 of Set 8 | pachino
# Processing Record 10 of Set 8 | cherskiy
# Processing Record 11 of Set 8 | matara
# Processing Record 12 of Set 8 | thohoyandou
# Processing Record 13 of Set 8 | milton
# Processing Record 14 of Set 8 | gimli
# Processing Record 15 of Set 8 | paamiut
# Processing Record 16 of Set 8 | pangnirtung
# Processing Record 17 of Set 8 | portarlington
# Processing Record 18 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 8 | pilao arcado
# City not found. Skipping...
# Processing Record 20 of Set 8 | rantepao
# Processing Record 21 of Set 8 | bagdarin
# Processing Record 22 of Set 8 | vila velha
# Processing Record 23 of Set 8 | pombas
# Processing Record 24 of Set 8 | kruisfontein
# Processing Record 25 of Set 8 | mercedes
# Processing Record 26 of Set 8 | avare
# Processing Record 27 of Set 8 | sobolevo
# Processing Record 28 of Set 8 | shiyan
# Processing Record 29 of Set 8 | vilhena
# Processing Record 30 of Set 8 | plettenberg bay
# Processing Record 31 of Set 8 | korla
# Processing Record 32 of Set 8 | kristiansund
# Processing Record 33 of Set 8 | ornskoldsvik
# Processing Record 34 of Set 8 | otane
# Processing Record 35 of Set 8 | poya
# Processing Record 36 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 37 of Set 8 | zolotinka
# City not found. Skipping...
# Processing Record 38 of Set 8 | lufilufi
# Processing Record 39 of Set 8 | katherine
# Processing Record 40 of Set 8 | nanortalik
# Processing Record 41 of Set 8 | guerrero negro
# Processing Record 42 of Set 8 | kisanga
# Processing Record 43 of Set 8 | yumen
# Processing Record 44 of Set 8 | schwarzenberg
# Processing Record 45 of Set 8 | san felipe
# Processing Record 46 of Set 8 | warwick
# Processing Record 47 of Set 8 | thyboron
# Processing Record 48 of Set 8 | terrasini
# Processing Record 49 of Set 8 | tingrela
# City not found. Skipping...
# Processing Record 50 of Set 8 | valdez
# Processing Record 1 of Set 9 | sistranda
# Processing Record 2 of Set 9 | puro
# Processing Record 3 of Set 9 | saint-denis
# Processing Record 4 of Set 9 | nordenham
# Processing Record 5 of Set 9 | mumford
# Processing Record 6 of Set 9 | mikhaylovka
# Processing Record 7 of Set 9 | tokyo
# Processing Record 8 of Set 9 | otavi
# Processing Record 9 of Set 9 | likhovskoy
# Processing Record 10 of Set 9 | key west
# Processing Record 11 of Set 9 | nauta
# Processing Record 12 of Set 9 | hualmay
# Processing Record 13 of Set 9 | outlook
# Processing Record 14 of Set 9 | banjar
# Processing Record 15 of Set 9 | bonnyville
# Processing Record 16 of Set 9 | mount isa
# Processing Record 17 of Set 9 | conde
# Processing Record 18 of Set 9 | dwarka
# Processing Record 19 of Set 9 | novo aripuana
# Processing Record 20 of Set 9 | necochea
# Processing Record 21 of Set 9 | goderich
# Processing Record 22 of Set 9 | tirat karmel
# Processing Record 23 of Set 9 | akyab
# Processing Record 24 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 9 | fare
# Processing Record 26 of Set 9 | karratha
# Processing Record 27 of Set 9 | kendari
# Processing Record 28 of Set 9 | marsa matruh
# Processing Record 29 of Set 9 | juneau
# Processing Record 30 of Set 9 | qeshm
# Processing Record 31 of Set 9 | kaeo
# Processing Record 32 of Set 9 | nuuk
# Processing Record 33 of Set 9 | immokalee
# Processing Record 34 of Set 9 | ayan
# Processing Record 35 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 9 | roma
# Processing Record 37 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 38 of Set 9 | san carlos
# Processing Record 39 of Set 9 | gaspe
# Processing Record 40 of Set 9 | ruwi
# Processing Record 41 of Set 9 | manica
# Processing Record 42 of Set 9 | ahipara
# Processing Record 43 of Set 9 | kaitangata
# Processing Record 44 of Set 9 | belousovka
# Processing Record 45 of Set 9 | te anau
# Processing Record 46 of Set 9 | lannion
# Processing Record 47 of Set 9 | dubbo
# Processing Record 48 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 9 | namatanai
# Processing Record 50 of Set 9 | yuancheng
# Processing Record 1 of Set 10 | san quintin
# Processing Record 2 of Set 10 | semnan
# Processing Record 3 of Set 10 | kenai
# Processing Record 4 of Set 10 | sola
# Processing Record 5 of Set 10 | lata
# Processing Record 6 of Set 10 | villa carlos paz
# Processing Record 7 of Set 10 | samarai
# Processing Record 8 of Set 10 | san patricio
# Processing Record 9 of Set 10 | saint-pierre
# Processing Record 10 of Set 10 | trelew
# Processing Record 11 of Set 10 | okhotsk
# Processing Record 12 of Set 10 | lieksa
# Processing Record 13 of Set 10 | liwale
# Processing Record 14 of Set 10 | noshiro
# Processing Record 15 of Set 10 | rubtsovsk
# Processing Record 16 of Set 10 | srednekolymsk
# Processing Record 17 of Set 10 | boa vista
# Processing Record 18 of Set 10 | acapulco
# Processing Record 19 of Set 10 | sangar
# Processing Record 20 of Set 10 | isla mujeres
# Processing Record 21 of Set 10 | scarborough
# Processing Record 22 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 10 | savannah bight
# Processing Record 24 of Set 10 | turukhansk
# Processing Record 25 of Set 10 | mingyue
# Processing Record 26 of Set 10 | kailua
# Processing Record 27 of Set 10 | brigantine
# Processing Record 28 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 10 | mizdah
# Processing Record 30 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 31 of Set 10 | nome
# Processing Record 32 of Set 10 | nhulunbuy
# Processing Record 33 of Set 10 | sorland
# Processing Record 34 of Set 10 | marsh harbour
# Processing Record 35 of Set 10 | santa isabel do rio negro
# Processing Record 36 of Set 10 | vardo
# Processing Record 37 of Set 10 | poronaysk
# Processing Record 38 of Set 10 | allanmyo
# City not found. Skipping...
# Processing Record 39 of Set 10 | pokhara
# Processing Record 40 of Set 10 | cabo san lucas
# Processing Record 41 of Set 10 | freeport
# Processing Record 42 of Set 10 | coolum beach
# Processing Record 43 of Set 10 | planadas
# Processing Record 44 of Set 10 | stornoway
# Processing Record 45 of Set 10 | wad rawah
# Processing Record 46 of Set 10 | poum
# Processing Record 47 of Set 10 | vuktyl
# Processing Record 48 of Set 10 | asau
# Processing Record 49 of Set 10 | darhan
# Processing Record 50 of Set 10 | itarema
# Processing Record 1 of Set 11 | the pas
# Processing Record 2 of Set 11 | ostrovnoy
# Processing Record 3 of Set 11 | kijang
# Processing Record 4 of Set 11 | san jose
# Processing Record 5 of Set 11 | sisimiut
# Processing Record 6 of Set 11 | dhidhdhoo
# Processing Record 7 of Set 11 | dicabisagan
# Processing Record 8 of Set 11 | metro
# Processing Record 9 of Set 11 | mukhen
# Processing Record 10 of Set 11 | chake chake
# Processing Record 11 of Set 11 | pozo colorado
# Processing Record 12 of Set 11 | ulladulla
# Processing Record 13 of Set 11 | yeppoon
# Processing Record 14 of Set 11 | inirida
# Processing Record 15 of Set 11 | lapy
# Processing Record 16 of Set 11 | sovetskaya gavan
# Processing Record 17 of Set 11 | catamarca
# Processing Record 18 of Set 11 | tutoia
# Processing Record 19 of Set 11 | vila
# Processing Record 20 of Set 11 | follonica
# Processing Record 21 of Set 11 | jingdezhen
# Processing Record 22 of Set 11 | olafsvik
# Processing Record 23 of Set 11 | lar
# Processing Record 24 of Set 11 | sanchazi
# Processing Record 25 of Set 11 | sao filipe
# Processing Record 26 of Set 11 | atka
# City not found. Skipping...
# Processing Record 27 of Set 11 | lagos
# Processing Record 28 of Set 11 | tazmalt
# Processing Record 29 of Set 11 | kalvarija
# Processing Record 30 of Set 11 | ketchikan
# Processing Record 31 of Set 11 | magui
# City not found. Skipping...
# Processing Record 32 of Set 11 | oktyabrskoye
# Processing Record 33 of Set 11 | gazanjyk
# Processing Record 34 of Set 11 | mmabatho
# Processing Record 35 of Set 11 | luderitz
# Processing Record 36 of Set 11 | pochutla
# Processing Record 37 of Set 11 | arlit
# Processing Record 38 of Set 11 | fenyi
# Processing Record 39 of Set 11 | chenghai
# Processing Record 40 of Set 11 | stephenville
# Processing Record 41 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 42 of Set 11 | champerico
# Processing Record 43 of Set 11 | san policarpo
# Processing Record 44 of Set 11 | aden
# Processing Record 45 of Set 11 | harper
# Processing Record 46 of Set 11 | bubaque
# Processing Record 47 of Set 11 | natal
# Processing Record 48 of Set 11 | sofiysk
# City not found. Skipping...
# Processing Record 49 of Set 11 | kimberley
# Processing Record 50 of Set 11 | yacuiba
# Processing Record 1 of Set 12 | alice springs
# Processing Record 2 of Set 12 | alofi
# Processing Record 3 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 12 | huangyan
# Processing Record 5 of Set 12 | hereford
# Processing Record 6 of Set 12 | ye
# City not found. Skipping...
# Processing Record 7 of Set 12 | nanchang
# Processing Record 8 of Set 12 | burley
# Processing Record 9 of Set 12 | rundu
# Processing Record 10 of Set 12 | palestine
# Processing Record 11 of Set 12 | camana
# Processing Record 12 of Set 12 | port blair
# Processing Record 13 of Set 12 | balabac
# Processing Record 14 of Set 12 | dalvik
# Processing Record 15 of Set 12 | lethem
# Processing Record 16 of Set 12 | khandbari
# Processing Record 17 of Set 12 | cockburn town
# Processing Record 18 of Set 12 | port lincoln
# Processing Record 19 of Set 12 | beringovskiy
# Processing Record 20 of Set 12 | blackwater
# Processing Record 21 of Set 12 | pucara
# Processing Record 22 of Set 12 | grand forks
# Processing Record 23 of Set 12 | huzhou
# Processing Record 24 of Set 12 | muisne
# Processing Record 25 of Set 12 | avera
# Processing Record 26 of Set 12 | palana
# Processing Record 27 of Set 12 | nagapattinam
# Processing Record 28 of Set 12 | myitkyina
# Processing Record 29 of Set 12 | seybaplaya
# Processing Record 30 of Set 12 | carnarvon
# Processing Record 31 of Set 12 | nizhniy kuranakh
# Processing Record 32 of Set 12 | grindavik
# Processing Record 33 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 34 of Set 12 | riesi
# Processing Record 35 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 36 of Set 12 | awjilah
# Processing Record 37 of Set 12 | duncan
# Processing Record 38 of Set 12 | keffi
# Processing Record 39 of Set 12 | aklavik
# Processing Record 40 of Set 12 | manga
# Processing Record 41 of Set 12 | charters towers
# Processing Record 42 of Set 12 | hurghada
# Processing Record 43 of Set 12 | adrar
# Processing Record 44 of Set 12 | nibbar
# Processing Record 45 of Set 12 | mastic beach
# Processing Record 46 of Set 12 | tarko-sale
# Processing Record 47 of Set 12 | yarmouth
# Processing Record 48 of Set 12 | kloulklubed
# Processing Record 49 of Set 12 | bereda
# Processing Record 50 of Set 12 | ponferrada
# Processing Record 1 of Set 13 | marsabit
# Processing Record 2 of Set 13 | karpathos
# Processing Record 3 of Set 13 | nemuro
# Processing Record 4 of Set 13 | san cristobal
# Processing Record 5 of Set 13 | saint anthony
# Processing Record 6 of Set 13 | caravelas
# Processing Record 7 of Set 13 | nara
# Processing Record 8 of Set 13 | eureka
# Processing Record 9 of Set 13 | tambovka
# Processing Record 10 of Set 13 | nchelenge
# Processing Record 11 of Set 13 | krk
# Processing Record 12 of Set 13 | thinadhoo
# Processing Record 13 of Set 13 | vaitape
# Processing Record 14 of Set 13 | pajapan
# Processing Record 15 of Set 13 | erzin
# Processing Record 16 of Set 13 | bombay
# Processing Record 17 of Set 13 | fort nelson
# Processing Record 18 of Set 13 | yar-sale
# Processing Record 19 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 13 | udala
# Processing Record 21 of Set 13 | yinchuan
# Processing Record 22 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 23 of Set 13 | itoman
# Processing Record 24 of Set 13 | naraini
# Processing Record 25 of Set 13 | suzhou
# Processing Record 26 of Set 13 | kokstad
# Processing Record 27 of Set 13 | parana
# Processing Record 28 of Set 13 | barcelona
# Processing Record 29 of Set 13 | morant bay
# Processing Record 30 of Set 13 | arawa
# Processing Record 31 of Set 13 | makakilo city
# Processing Record 32 of Set 13 | riyadh
# Processing Record 33 of Set 13 | erenhot
# Processing Record 34 of Set 13 | muros
# Processing Record 35 of Set 13 | lasa
# Processing Record 36 of Set 13 | araouane
# Processing Record 37 of Set 13 | bandarbeyla
# Processing Record 38 of Set 13 | sao joao da barra
# Processing Record 39 of Set 13 | novochernorechenskiy
# Processing Record 40 of Set 13 | kieta
# Processing Record 41 of Set 13 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 42 of Set 13 | beaverlodge
# Processing Record 43 of Set 13 | petropavl
# Processing Record 44 of Set 13 | jaguaribe
# Processing Record 45 of Set 13 | talas
# Processing Record 46 of Set 13 | lagunas
# Processing Record 47 of Set 13 | chita
# Processing Record 48 of Set 13 | humaita
# Processing Record 49 of Set 13 | joao pinheiro
# Processing Record 50 of Set 13 | diego de almagro
# Processing Record 1 of Set 14 | sorong
# Processing Record 2 of Set 14 | ancud
# Processing Record 3 of Set 14 | whitehorse
# Processing Record 4 of Set 14 | nantucket
# Processing Record 5 of Set 14 | stawell
# Processing Record 6 of Set 14 | fairbanks
# Processing Record 7 of Set 14 | misratah
# Processing Record 8 of Set 14 | auxerre
# Processing Record 9 of Set 14 | ayolas
# Processing Record 10 of Set 14 | hohhot
# Processing Record 11 of Set 14 | oranjestad
# Processing Record 12 of Set 14 | port-gentil
# Processing Record 13 of Set 14 | vladivostok
# Processing Record 14 of Set 14 | smidovich
# Processing Record 15 of Set 14 | nelson bay
# Processing Record 16 of Set 14 | alyangula
# Processing Record 17 of Set 14 | houma
# Processing Record 18 of Set 14 | college
# Processing Record 19 of Set 14 | paranapanema
# Processing Record 20 of Set 14 | waipawa
# Processing Record 21 of Set 14 | azle
# Processing Record 22 of Set 14 | novaya ladoga
# Processing Record 23 of Set 14 | visby
# Processing Record 24 of Set 14 | sao gabriel da cachoeira
# Processing Record 25 of Set 14 | russas
# Processing Record 26 of Set 14 | mwene-ditu
# Processing Record 27 of Set 14 | cobija
# Processing Record 28 of Set 14 | mount gambier
# Processing Record 29 of Set 14 | dovolnoye
# Processing Record 30 of Set 14 | aksarka
# Processing Record 31 of Set 14 | north bend
# Processing Record 32 of Set 14 | shahrud
# Processing Record 33 of Set 14 | vestmanna
# Processing Record 34 of Set 14 | port hardy
# Processing Record 35 of Set 14 | udachnyy
# Processing Record 36 of Set 14 | terrace
# Processing Record 37 of Set 14 | cortez
# Processing Record 38 of Set 14 | elizabeth city
# Processing Record 39 of Set 14 | batemans bay
# Processing Record 40 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 14 | kokopo
# Processing Record 42 of Set 14 | laguna
# Processing Record 43 of Set 14 | vidim
# Processing Record 44 of Set 14 | hornepayne
# Processing Record 45 of Set 14 | sibolga
# Processing Record 46 of Set 14 | kobryn
# Processing Record 47 of Set 14 | la sarre
# Processing Record 48 of Set 14 | yanliang
# Processing Record 49 of Set 14 | gorele
# Processing Record 50 of Set 14 | carman
# Processing Record 1 of Set 15 | maniitsoq
# Processing Record 2 of Set 15 | shchelyayur
# City not found. Skipping...
# Processing Record 3 of Set 15 | chernyshevskiy
# Processing Record 4 of Set 15 | great yarmouth
# Processing Record 5 of Set 15 | tres arroyos
# Processing Record 6 of Set 15 | westport
# Processing Record 7 of Set 15 | rocha
# Processing Record 8 of Set 15 | sindand
# City not found. Skipping...
# Processing Record 9 of Set 15 | esna
# Processing Record 10 of Set 15 | maryville
# Processing Record 11 of Set 15 | burns lake
# Processing Record 12 of Set 15 | batagay
# Processing Record 13 of Set 15 | lundazi
# Processing Record 14 of Set 15 | marzuq
# Processing Record 15 of Set 15 | dzaoudzi
# Processing Record 16 of Set 15 | primo tapia
# Processing Record 17 of Set 15 | mubi
# Processing Record 18 of Set 15 | kununurra
# Processing Record 19 of Set 15 | kefamenanu
# Processing Record 20 of Set 15 | miri
# Processing Record 21 of Set 15 | nizwa
# Processing Record 22 of Set 15 | canyon
# Processing Record 23 of Set 15 | obzor
# Processing Record 24 of Set 15 | makarov
# Processing Record 25 of Set 15 | carhuaz
# Processing Record 26 of Set 15 | hobyo
# Processing Record 27 of Set 15 | egvekinot
# Processing Record 28 of Set 15 | burica
# City not found. Skipping...
# Processing Record 29 of Set 15 | aktash
# Processing Record 30 of Set 15 | gizo
# Processing Record 31 of Set 15 | cabrobo
# Processing Record 32 of Set 15 | pingliang
# Processing Record 33 of Set 15 | baykit
# Processing Record 34 of Set 15 | pontes e lacerda
# Processing Record 35 of Set 15 | carupano
# Processing Record 36 of Set 15 | solsvik
# City not found. Skipping...
# Processing Record 37 of Set 15 | grobina
# Processing Record 38 of Set 15 | wladyslawowo
# Processing Record 39 of Set 15 | pauini
# Processing Record 40 of Set 15 | tabou
# Processing Record 41 of Set 15 | abancay
# Processing Record 42 of Set 15 | vilyuysk
# Processing Record 43 of Set 15 | sao jose da coroa grande
# Processing Record 44 of Set 15 | san luis
# Processing Record 45 of Set 15 | praia
# Processing Record 46 of Set 15 | sukhoverkovo
# City not found. Skipping...
# Processing Record 47 of Set 15 | saint-paul-les-dax
# Processing Record 48 of Set 15 | mogadishu
# Processing Record 49 of Set 15 | manaure
# Processing Record 50 of Set 15 | hamilton
# Processing Record 1 of Set 16 | otjimbingwe
# Processing Record 2 of Set 16 | qasigiannguit
# Processing Record 3 of Set 16 | tiarei
# Processing Record 4 of Set 16 | cap malheureux
# Processing Record 5 of Set 16 | talesh
# City not found. Skipping...
# Processing Record 6 of Set 16 | sikea
# City not found. Skipping...
# Processing Record 7 of Set 16 | zhanaozen
# Processing Record 8 of Set 16 | falealupo
# City not found. Skipping...
# Processing Record 9 of Set 16 | cacota
# Processing Record 10 of Set 16 | balingasay
# Processing Record 11 of Set 16 | kyabe
# Processing Record 12 of Set 16 | rio grande
# Processing Record 13 of Set 16 | puerto escondido
# Processing Record 14 of Set 16 | bilibino
# Processing Record 15 of Set 16 | casper
# Processing Record 16 of Set 16 | mirnyy
# Processing Record 17 of Set 16 | francistown
# Processing Record 18 of Set 16 | koulikoro
# Processing Record 19 of Set 16 | salaga
# Processing Record 20 of Set 16 | two rivers
# Processing Record 21 of Set 16 | podbrdo
# Processing Record 22 of Set 16 | bykovo
# Processing Record 23 of Set 16 | zatoka
# Processing Record 24 of Set 16 | jardim
# Processing Record 25 of Set 16 | nichinan
# Processing Record 26 of Set 16 | lorengau
# Processing Record 27 of Set 16 | mantua
# Processing Record 28 of Set 16 | santa rosa
# Processing Record 29 of Set 16 | paraibano
# Processing Record 30 of Set 16 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 16 | conceicao do araguaia
# Processing Record 32 of Set 16 | phetchaburi
# Processing Record 33 of Set 16 | derbent
# Processing Record 34 of Set 16 | taltal
# Processing Record 35 of Set 16 | kuching
# Processing Record 36 of Set 16 | rantoul
# Processing Record 37 of Set 16 | bastrop
# Processing Record 38 of Set 16 | pundaguitan
# Processing Record 39 of Set 16 | barbar
# City not found. Skipping...
# Processing Record 40 of Set 16 | hovd
# Processing Record 41 of Set 16 | burriana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Ossora  59.24  163.07     31.28        96          54        5.79
# 1   Busselton -33.65  115.33     55.00        97           8        9.84
# 2   Mahebourg -20.41   57.70     73.40        64          75       11.41
# 3  Codrington -38.27  141.97     61.14        55          99        9.19
# 4   Tilichiki  60.47  166.10     28.44       100         100        1.59
# 5   Tuatapere -46.13  167.68     39.99        93          51        1.01
# 6      Atuona  -9.80 -139.03     77.52        76          60       20.11
# 7      Imuris  30.78 -110.87     79.09        22          55        9.53
# 8       Vaini -21.20 -175.20     73.40        94          75        9.17
# 9   Algeciras  36.13   -5.45     64.40        88           0        6.93
#
#   Country                 Date
# 0      RU  2020-11-02 17:29:26
# 1      AU  2020-11-02 17:28:42
# 2      MU  2020-11-02 17:29:26
# 3      AU  2020-11-02 17:27:11
# 4      RU  2020-11-02 17:27:15
# 5      NZ  2020-11-02 17:24:45
# 6      PF  2020-11-02 17:29:26
# 7      MX  2020-11-02 17:29:27
# 8      TO  2020-11-02 17:27:10
# 9      ES  2020-11-02 17:29:27

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
