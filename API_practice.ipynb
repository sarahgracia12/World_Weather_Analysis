# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = (zip(x, y))
coordinates

# %%
coordinates = list(coordinates)
coordinates
# Out:
# [(25.12903645, -67.59741259),
#  (25.92017388, 11.09532135),
#  (26.62509167, 74.84233102),
#  (-59.98969384, -76.89176677),
#  (37.30571269, -61.13376282)]

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(type(coordinate[0]))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# cockburn town tc
# gat ly
# parvatsar in
# punta arenas cl
# saint george bm

# %%
# import requests library 
import requests

# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e43cf2ff3dd723d916a3acbdadfe7598

# %%
# Create an endpoint URL for a city 
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e43cf2ff3dd723d916a3acbdadfe7598&q=Boston

# %%
# Make a 'Get' request for the city weather 
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city 
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city 
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request
city_weather.text
# Out:
# '{"coord":{"lon":-71.06,"lat":42.36},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"base":"stations","main":{"temp":49.82,"feels_like":43.77,"temp_min":48,"temp_max":51.01,"pressure":1015,"humidity":70},"visibility":10000,"wind":{"speed":6.93,"deg":180},"clouds":{"all":90},"dt":1604255789,"sys":{"type":1,"id":3486,"country":"US","sunrise":1604229485,"sunset":1604266645},"timezone":-18000,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request 
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 49.82,
#   'feels_like': 43.77,
#   'temp_min': 48,
#   'temp_max': 51.01,
#   'pressure': 1015,
#   'humidity': 70},
#  'visibility': 10000,
#  'wind': {'speed': 6.93, 'deg': 180},
#  'clouds': {'all': 90},
#  'dt': 1604255789,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1604229485,
#   'sunset': 1604266645},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city 
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found")
else:
    print(f"City weather not found")
# Out:
# City Weather found

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e43cf2ff3dd723d916a3acbdadfe7598&q=Bston

# %%
# Create an endpoint URL for a city 
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 49.86,
#   'feels_like': 43.83,
#   'temp_min': 48,
#   'temp_max': 51.01,
#   'pressure': 1015,
#   'humidity': 70},
#  'visibility': 10000,
#  'wind': {'speed': 6.93, 'deg': 180},
#  'clouds': {'all': 90},
#  'dt': 1604256358,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1604229485,
#   'sunset': 1604266645},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}
